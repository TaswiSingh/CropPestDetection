# %% [markdown]
# # 05 Inference (RPi template)
# Collect 30s baseline + 120s acquisition + 60s recovery @10Hz, pack readings dict, call predict_live(). No scaler needed.

# %%
import sys; sys.path.insert(0, '..')
from src.predict import Predictor
p = Predictor(model_dir='../models')
print(p.predict_csv_sample('/kaggle/input/tomato-thrips-enose/e_nose_thrips_60rep_per_treat_time.csv', 'S00061'))
# Live: p.predict_live({'Time_s': [...], 'Phase': [...], 'TGS2600': [...], ...}, {'SampleID': 'GREENHOUSE-01'})
