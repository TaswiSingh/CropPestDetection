# %% [markdown]
# # 06 Results — verdict: gate PASS, shipping XGB defaults
# Figures are prebuilt PNGs (`python src/plots.py`), displayed here for Kaggle without recompute.

# %% [markdown]
# **Verdict 1: caught at 1h.** All real models hit Pest recall 1.00 in the pre-symptomatic window.

# %%
from IPython.display import Image
Image('reports/figures/early_recall_curve.png')

# %% [markdown]
# **Verdict 2: rarely cries wolf.** Mechanical→Pest 4%, inside the 5% spray limit.

# %%
Image('reports/figures/confusion_head1.png')

# %% [markdown]
# **Verdict 3: nitrogen sensors decide.** MiCS NO2/NH3 carry the gain — HIPV biology, not background.

# %%
Image('reports/figures/importance_top15.png')

# %% [markdown]
# **Severity grading waits a day; warning does not.** Head-2 resolves Low/Med/High at 24h+ (0.80–0.87).

# %%
Image('reports/figures/head2_time_curve.png')

# %% [markdown]
# **Tuning defense:** 20-trial Optuna flat at ceiling — defaults ship.

# %%
Image('reports/figures/ceiling_bars.png')
