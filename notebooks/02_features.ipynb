# %% [markdown]
# # 02 Features (writes /kaggle/output/features.parquet)
# Chunked: safe for 880MB.

# %%
import os, sys
sys.path.insert(0, '..')
from src.features import build_features_csv
IN = '/kaggle/input/tomato-thrips-enose/e_nose_thrips_60rep_per_treat_time.csv'
IN = IN if os.path.exists(IN) else '../e_nose_thrips_60rep_per_treat_time.csv'
print(build_features_csv(IN, '/kaggle/working/features.parquet'))
