# %% [markdown]
# # 03 Head-1: Control / Mechanical / Pest (Kaggle CPU)
# Objective = mean Pest-recall on Time_h in [1,3,6]. Folds grouped by plant_id.

# %%
import sys; sys.path.insert(0, '..')
from src.train_baseline import main
main('../processed/features.parquet' if False else '/kaggle/input/tomato-thrips-enose/features.parquet', 20, '/kaggle/working/baseline_head1.json')
