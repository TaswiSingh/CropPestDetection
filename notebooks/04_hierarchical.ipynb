# %% [markdown]
# # 04 Hierarchical: Head-2 severity on pest-only rows
# Expect weakness at 1h (VOC quantity insufficient); success = Head-1 early catch + Head-2 late resolve.

# %%
import sys; sys.path.insert(0, '..')
from src.train_head2 import main
main('/kaggle/input/tomato-thrips-enose/features.parquet', '/kaggle/working/head2.json')
